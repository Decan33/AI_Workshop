# %%
# !pip install scikit-optimize
# Out:
# Collecting scikit-optimize
#   Downloading scikit_optimize-0.10.2-py2.py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.8/107.8 kB 22.6 MB/s eta 0:00:00
# Requirement already satisfied: joblib>=0.11 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from scikit-optimize) (1.3.2)
# Collecting pyaml>=16.9 (from scikit-optimize)
#   Downloading pyaml-24.4.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: numpy>=1.20.3 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from scikit-optimize) (1.26.1)
# Requirement already satisfied: scipy>=1.1.0 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from scikit-optimize) (1.11.3)
# Requirement already satisfied: scikit-learn>=1.0.0 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from scikit-optimize) (1.3.1)
# Requirement already satisfied: packaging>=21.3 in /shared-libs/python3.11/py-core/lib/python3.11/site-packages (from scikit-optimize) (23.2)
# Requirement already satisfied: PyYAML in /shared-libs/python3.11/py-core/lib/python3.11/site-packages (from pyaml>=16.9->scikit-optimize) (6.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from scikit-learn>=1.0.0->scikit-optimize) (3.2.0)
# Installing collected packages: pyaml, scikit-optimize
# Successfully installed pyaml-24.4.0 scikit-optimize-0.10.2
#
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import LabelEncoder, StandardScaler
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_absolute_error
import numpy as np
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from skopt import BayesSearchCV

df = pd.read_csv("./materials.csv")

selected_features = [
    "band_gap",
    "is_metal",
    "formation_energy_per_atom",
    "efermi",
    "ordering",
    "total_magnetization_normalized_vol",
    "total_magnetization",
    "num_magnetic_sites",
    "density",
    "density_atomic",
]

df = df[selected_features]

# %%
df.dropna(inplace=True)

# %%
label_encoder = LabelEncoder()

df["ordering"] = label_encoder.fit_transform(df["ordering"])
df["is_metal"] = label_encoder.fit_transform(df["is_metal"])

# %%
X = df.drop(columns=["band_gap"])
y = df["band_gap"]

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# %%
param_dist = {
    'n_estimators': [100, 200, 300, 400, 500],
    'max_depth': [10, 50, 100, 200, 400],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

search_space = {
    'n_estimators': (100, 500),
    'max_depth': (10, 400),
    'min_samples_split': (2, 10),
    'min_samples_leaf': (1, 4)
}

rf = RandomForestRegressor(random_state=42)


# search = GridSearchCV(estimator=rf, param_grid=param_dist, cv=3, n_jobs=-1, verbose=2)
search = RandomizedSearchCV(estimator=rf, param_distributions=param_dist, n_iter=50, cv=3, n_jobs=-1, verbose=2, random_state=42)
# search = BayesSearchCV(estimator=rf, search_spaces=search_space, n_iter=32, cv=3, n_jobs=-1, verbose=2, random_state=42)

search.fit(X_train, y_train)

best_params = search.best_params_
print(f"Best parameters: {best_params}")

best_model = search.best_estimator_
best_model.fit(X_train, y_train)

# %%
y_pred = best_model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"Mean Absolute Error: {mae}")
print(f"R² Score: {r2}")

# %%
importances = best_model.feature_importances_
features = X.columns
indices = np.argsort(importances)

plt.figure(figsize=(10, 6))
plt.title("Feature Importances")
plt.barh(range(len(indices)), importances[indices], align="center")
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel("Relative Importance")
plt.show()


plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, alpha=0.5)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], "k--", lw=2)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted Values")
plt.show()
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=  53.6s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=  55.3s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=  53.4s
# [CV] END max_depth=400, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time= 1.2min
# [CV] END max_depth=400, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time= 1.3min
# [CV] END max_depth=400, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time= 1.3min
# [CV] END max_depth=100, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  13.0s
# [CV] END max_depth=100, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  13.2s
# [CV] END max_depth=100, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  13.4s
# [CV] END max_depth=400, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  39.8s
# [CV] END max_depth=400, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  40.9s
# [CV] END max_depth=400, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  40.9s
# [CV] END max_depth=200, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=  54.3s
# [CV] END max_depth=200, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=  55.5s
# [CV] END max_depth=200, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=  55.7s
# [CV] END max_depth=400, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time= 1.1min
# [CV] END max_depth=400, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time= 1.1min
# [CV] END max_depth=400, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time= 1.1min
# [CV] END max_depth=400, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  45.4s
# [CV] END max_depth=400, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  45.2s
# [CV] END max_depth=400, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=  46.3s
# [CV] END max_depth=50, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  25.4s
# [CV] END max_depth=50, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  25.8s
# [CV] END max_depth=50, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  26.1s
# [CV] END max_depth=200, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=  50.3s
# [CV] END max_depth=200, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=  52.1s
# [CV] END max_depth=200, min_samples_leaf=4, min_samples_split=10, n_estimators=400; total time=  52.3s
# [CV] END max_depth=200, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  12.7s
# [CV] END max_depth=200, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  12.7s
# [CV] END max_depth=200, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  12.8s
# [CV] END max_depth=50, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=  53.9s
# [CV] END max_depth=50, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=  54.8s
# [CV] END max_depth=50, min_samples_leaf=2, min_samples_split=5, n_estimators=400; total time=  55.6s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  10.5s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  10.9s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  10.9s
# [CV] END max_depth=400, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  13.6s
# [CV] END max_depth=400, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  13.2s
# [CV] END max_depth=400, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  13.5s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  10.5s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  10.6s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  10.8s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  10.3s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  10.7s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  10.7s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  14.7s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  14.8s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  14.6s
# [CV] END max_depth=50, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  13.7s
# [CV] END max_depth=50, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  13.9s
# [CV] END max_depth=50, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  13.5s
# [CV] END max_depth=200, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  25.4s
# [CV] END max_depth=200, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  25.8s
# [CV] END max_depth=200, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  26.1s
# [CV] END max_depth=100, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  26.8s
# [CV] END max_depth=100, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  29.0s
# [CV] END max_depth=100, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  27.7s
# [CV] END max_depth=200, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  12.8s
# [CV] END max_depth=200, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  12.9s
# [CV] END max_depth=200, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  13.3s
# [CV] END max_depth=50, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time= 1.0min
# [CV] END max_depth=50, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time= 1.1min
# [CV] END max_depth=50, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time= 1.1min
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  41.9s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  44.3s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  44.9s
# [CV] END max_depth=200, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  39.0s
# [CV] END max_depth=200, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  39.5s
# [CV] END max_depth=200, min_samples_leaf=4, min_samples_split=2, n_estimators=300; total time=  39.5s
# [CV] END max_depth=200, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  41.4s
# [CV] END max_depth=200, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  42.6s
# [CV] END max_depth=200, min_samples_leaf=2, min_samples_split=2, n_estimators=300; total time=  42.8s
# [CV] END max_depth=100, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  29.0s
# [CV] END max_depth=100, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  29.0s
# [CV] END max_depth=100, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  29.1s
# [CV] END max_depth=50, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  39.2s
# [CV] END max_depth=50, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  41.6s
# [CV] END max_depth=50, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  46.8s
# [CV] END max_depth=400, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=  58.7s
# [CV] END max_depth=400, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time= 1.0min
# [CV] END max_depth=400, min_samples_leaf=1, min_samples_split=10, n_estimators=400; total time=  58.2s
# [CV] END max_depth=200, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  41.6s
# [CV] END max_depth=200, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  40.0s
# [CV] END max_depth=200, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  39.8s
# [CV] END max_depth=400, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  12.7s
# [CV] END max_depth=400, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  13.3s
# [CV] END max_depth=400, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  13.1s
# [CV] END max_depth=100, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time= 1.1min
# [CV] END max_depth=100, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time= 1.2min
# [CV] END max_depth=100, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time= 1.2min
# [CV] END max_depth=100, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=  53.7s
# [CV] END max_depth=100, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=  54.2s
# [CV] END max_depth=100, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=  56.7s
# [CV] END max_depth=50, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  13.5s
# [CV] END max_depth=50, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  14.5s
# [CV] END max_depth=50, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  15.5s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  21.2s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  22.4s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  26.2s
# [CV] END max_depth=400, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  59.2s
# [CV] END max_depth=400, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  57.6s
# [CV] END max_depth=400, min_samples_leaf=2, min_samples_split=2, n_estimators=400; total time=  57.5s
# [CV] END max_depth=400, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  27.6s
# [CV] END max_depth=400, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  27.7s
# [CV] END max_depth=400, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  26.4s
# [CV] END max_depth=100, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  37.6s
# [CV] END max_depth=100, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  39.9s
# [CV] END max_depth=100, min_samples_leaf=2, min_samples_split=10, n_estimators=300; total time=  41.6s
# [CV] END max_depth=400, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  13.8s
# [CV] END max_depth=400, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  14.4s
# [CV] END max_depth=400, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  14.3s
# [CV] END max_depth=100, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time= 1.3min
# [CV] END max_depth=100, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time= 1.3min
# [CV] END max_depth=100, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time= 1.3min
# [CV] END max_depth=100, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  30.7s
# [CV] END max_depth=100, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  31.7s
# [CV] END max_depth=100, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  31.7s
# [CV] END max_depth=200, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time= 1.4min
# [CV] END max_depth=200, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time= 1.4min
# [CV] END max_depth=200, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time= 1.5min
# [CV] END max_depth=200, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  35.5s
# [CV] END max_depth=200, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  33.3s
# [CV] END max_depth=200, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=  31.8s
# [CV] END max_depth=400, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=  57.3s
# [CV] END max_depth=400, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=  58.3s
# [CV] END max_depth=400, min_samples_leaf=4, min_samples_split=2, n_estimators=400; total time=  58.8s
# [CV] END max_depth=200, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time= 1.0min
# [CV] END max_depth=200, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time= 1.1min
# [CV] END max_depth=200, min_samples_leaf=1, min_samples_split=5, n_estimators=400; total time= 1.1min
# [CV] END max_depth=400, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  42.7s
# [CV] END max_depth=400, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  43.7s
# [CV] END max_depth=400, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  43.0s
# [CV] END max_depth=200, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  46.7s
# [CV] END max_depth=200, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  47.7s
# [CV] END max_depth=200, min_samples_leaf=1, min_samples_split=5, n_estimators=300; total time=  47.6s
# [CV] END max_depth=200, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=  58.6s
# [CV] END max_depth=200, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time=  59.9s
# [CV] END max_depth=200, min_samples_leaf=2, min_samples_split=10, n_estimators=400; total time= 1.0min
# [CV] END max_depth=50, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  45.5s
# [CV] END max_depth=50, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  46.4s
# [CV] END max_depth=50, min_samples_leaf=2, min_samples_split=5, n_estimators=300; total time=  47.1s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  14.7s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  15.1s
# [CV] END max_depth=50, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  15.7s
# [CV] END max_depth=100, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time= 1.2min
# [CV] END max_depth=100, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time= 1.2min
# [CV] END max_depth=100, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time= 1.2min
# [CV] END max_depth=100, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  43.8s
# [CV] END max_depth=100, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  44.4s
# [CV] END max_depth=100, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time=  44.2s
# Best parameters: {'n_estimators': 500, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_depth': 400}
# Mean Squared Error: 0.2244982554482577
# Mean Absolute Error: 0.20999012871908027
# R² Score: 0.8741563741708029

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=f0446739-2868-4c9a-a5f3-c906e43fac85' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
