# %%
# !pip install featurewiz
# Out:
# Requirement already satisfied: featurewiz in /usr/local/lib/python3.10/dist-packages (0.5.7)
# Requirement already satisfied: Pillow>=9.0.0 in /usr/local/lib/python3.10/dist-packages (from featurewiz) (9.4.0)
# Requirement already satisfied: category-encoders>=2.6.2 in /usr/local/lib/python3.10/dist-packages (from featurewiz) (2.6.3)
# Requirement already satisfied: dask>=2021.11.0 in /usr/local/lib/python3.10/dist-packages (from featurewiz) (2023.8.1)
# Requirement already satisfied: distributed>=2021.11.0 in /usr/local/lib/python3.10/dist-packages (from featurewiz) (2023.8.1)
# Requirement already satisfied: feather-format>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from featurewiz) (0.4.1)
# Requirement already satisfied: fsspec>=0.3.3 in /usr/local/lib/python3.10/dist-packages (from featurewiz) (2023.6.0)
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from featurewiz) (7.34.0)
# Requirement already satisfied: jupyter in /usr/local/lib/python3.10/dist-packages (from featurewiz) (1.0.0)
# Requirement already satisfied: lazytransform>=1.16 in /usr/local/lib/python3.10/dist-packages (from featurewiz) (1.16)
# Requirement already satisfied: lightgbm>=3.2.1 in /usr/local/lib/python3.10/dist-packages (from featurewiz) (4.1.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from featurewiz) (3.7.1)
# Requirement already satisfied: networkx>=2.6.2 in /usr/local/lib/python3.10/dist-packages (from featurewiz) (3.3)
# Requirement already satisfied: numexpr>=2.7.3 in /usr/local/lib/python3.10/dist-packages (from featurewiz) (2.10.0)
# Requirement already satisfied: pandas<2.0,>=1.3.4 in /usr/local/lib/python3.10/dist-packages (from featurewiz) (1.5.3)
# Requirement already satisfied: pyarrow>=7.0.0 in /usr/local/lib/python3.10/dist-packages (from featurewiz) (14.0.2)
# Requirement already satisfied: scikit-learn<=1.2.2,>=0.24 in /usr/local/lib/python3.10/dist-packages (from featurewiz) (1.2.2)
# Requirement already satisfied: scipy<1.11.0 in /usr/local/lib/python3.10/dist-packages (from featurewiz) (1.10.1)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (from featurewiz) (0.13.1)
# Requirement already satisfied: tqdm>=4.61.1 in /usr/local/lib/python3.10/dist-packages (from featurewiz) (4.66.4)
# Requirement already satisfied: xgboost<=1.6.2,>=1.5 in /usr/local/lib/python3.10/dist-packages (from featurewiz) (1.6.2)
# Requirement already satisfied: xlrd>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from featurewiz) (2.0.1)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from category-encoders>=2.6.2->featurewiz) (1.25.2)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from category-encoders>=2.6.2->featurewiz) (0.14.2)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.10/dist-packages (from category-encoders>=2.6.2->featurewiz) (0.5.6)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2021.11.0->featurewiz) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2021.11.0->featurewiz) (2.2.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2021.11.0->featurewiz) (24.1)
# Requirement already satisfied: partd>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2021.11.0->featurewiz) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from dask>=2021.11.0->featurewiz) (6.0.1)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2021.11.0->featurewiz) (0.12.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2021.11.0->featurewiz) (7.1.0)
# Requirement already satisfied: jinja2>=2.10.3 in /usr/local/lib/python3.10/dist-packages (from distributed>=2021.11.0->featurewiz) (3.1.4)
# Requirement already satisfied: locket>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2021.11.0->featurewiz) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2021.11.0->featurewiz) (1.0.8)
# Requirement already satisfied: psutil>=5.7.2 in /usr/local/lib/python3.10/dist-packages (from distributed>=2021.11.0->featurewiz) (5.9.5)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /usr/local/lib/python3.10/dist-packages (from distributed>=2021.11.0->featurewiz) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2021.11.0->featurewiz) (3.0.0)
# Requirement already satisfied: tornado>=6.0.4 in /usr/local/lib/python3.10/dist-packages (from distributed>=2021.11.0->featurewiz) (6.3.3)
# Requirement already satisfied: urllib3>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from distributed>=2021.11.0->featurewiz) (2.0.7)
# Requirement already satisfied: zict>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from distributed>=2021.11.0->featurewiz) (3.0.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from lazytransform>=1.16->featurewiz) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->featurewiz) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->featurewiz) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->featurewiz) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->featurewiz) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->featurewiz) (3.1.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.0,>=1.3.4->featurewiz) (2023.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<=1.2.2,>=0.24->featurewiz) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<=1.2.2,>=0.24->featurewiz) (3.5.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython->featurewiz) (67.7.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython->featurewiz) (0.19.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython->featurewiz) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->featurewiz) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython->featurewiz) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->featurewiz) (3.0.47)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython->featurewiz) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->featurewiz) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->featurewiz) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->featurewiz) (4.9.0)
# Requirement already satisfied: notebook in /usr/local/lib/python3.10/dist-packages (from jupyter->featurewiz) (6.5.5)
# Requirement already satisfied: qtconsole in /usr/local/lib/python3.10/dist-packages (from jupyter->featurewiz) (5.5.2)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.10/dist-packages (from jupyter->featurewiz) (6.1.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.10/dist-packages (from jupyter->featurewiz) (6.5.4)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.10/dist-packages (from jupyter->featurewiz) (5.5.6)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.10/dist-packages (from jupyter->featurewiz) (7.7.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.13.0->dask>=2021.11.0->featurewiz) (3.19.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython->featurewiz) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.10.3->distributed>=2021.11.0->featurewiz) (2.1.5)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.1->category-encoders>=2.6.2->featurewiz) (1.16.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->featurewiz) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->featurewiz) (0.2.13)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter->featurewiz) (0.2.0)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter->featurewiz) (6.1.12)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->jupyter->featurewiz) (3.6.6)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->jupyter->featurewiz) (3.0.11)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->featurewiz) (4.9.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->featurewiz) (4.12.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->featurewiz) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->featurewiz) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->featurewiz) (0.4)
# Requirement already satisfied: jupyter-core>=4.7 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->featurewiz) (5.7.2)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->featurewiz) (0.3.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->featurewiz) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->featurewiz) (0.10.0)
# Requirement already satisfied: nbformat>=5.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->featurewiz) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->featurewiz) (1.5.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter->featurewiz) (1.3.0)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->featurewiz) (24.0.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->featurewiz) (23.1.0)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->featurewiz) (1.6.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->featurewiz) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->featurewiz) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->featurewiz) (0.20.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter->featurewiz) (1.1.0)
# Requirement already satisfied: qtpy>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from qtconsole->jupyter->featurewiz) (2.4.1)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.7->nbconvert->jupyter->featurewiz) (4.2.2)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook->jupyter->featurewiz) (0.2.4)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.1->nbconvert->jupyter->featurewiz) (2.19.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.1->nbconvert->jupyter->featurewiz) (4.19.2)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook->jupyter->featurewiz) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert->jupyter->featurewiz) (2.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert->jupyter->featurewiz) (0.5.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->featurewiz) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->featurewiz) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->featurewiz) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert->jupyter->featurewiz) (0.18.1)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.10/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->jupyter->featurewiz) (1.24.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->featurewiz) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->featurewiz) (2.22)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->jupyter->featurewiz) (3.7.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->jupyter->featurewiz) (1.8.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->jupyter->featurewiz) (3.7)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->jupyter->featurewiz) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->jupyter->featurewiz) (1.2.1)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from featurewiz import featurewiz
from sklearn.preprocessing import LabelEncoder


df = pd.read_csv('materials.csv')

df.drop(columns=['material_id', 'formula_pretty'], axis=1, inplace=True)

df.dropna(inplace=True)

label_encoder = LabelEncoder()

df['is_magnetic'] = label_encoder.fit_transform(df['is_magnetic'])
df['ordering'] = label_encoder.fit_transform(df['ordering'])
df['is_gap_direct'] = label_encoder.fit_transform(df['is_gap_direct'])
df['is_metal'] = label_encoder.fit_transform(df['is_metal'])

# %%
scaler = StandardScaler()

scaled = scaler.fit_transform(df)

scaled_df = pd.DataFrame(scaled, columns=df.columns)

# %%
X = scaled_df.drop(['band_gap'],axis=1)

y = scaled_df['band_gap']

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X,y,test_size = 0.2,random_state=1)

# %%
target = 'band_gap'

features, train = featurewiz(df, target, corr_limit=0.7, verbose=2, sep=",",
header=0,test_data="", feature_engg="", category_encoders="")

print(features)
# Out:
# ############################################################################################
# ############       F A S T   F E A T U R E  E N G G    A N D    S E L E C T I O N ! ########
# # Be judicious with featurewiz. Don't use it to create too many un-interpretable features! #
# ############################################################################################
# featurewiz has selected 0.7 as the correlation limit. Change this limit to fit your needs...
#     Skipping feature engineering since no feature_engg input...
# Skipping category encoding since no category encoders specified in input...
#     Single_Label Regression problem
#     Loaded train data. Shape = (66933, 31)
#     Single_Label Regression problem
# No test data filename given...
# Classifying features using a random sample of 10000 rows from dataset...
#     Single_Label Regression problem
#     loading a sequential sample of 10000 rows into pandas for EDA
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
#         1 variable(s) to be removed since ID or low-information variables
#     	variables removed = ['min_distance_matrix']
# train data shape before dropping 1 columns = (66933, 31)
# 	train data shape after dropping columns = (66933, 30)
# GPU active on this device
#     Tuning XGBoost using GPU hyper-parameters. This will take time...
# Removing 1 columns from further processing since ID or low information variables
#     After removing redundant variables from further processing, features left = 29
# No interactions created for categorical vars since feature engg does not specify it
# #######################################################################################
# #####  Searching for Uncorrelated List Of Variables (SULOV) in 29 features ############
# #######################################################################################
# Starting SULOV with 29 features...
#     there are no null values in dataset...
#     there are no null values in target column...
#     Removing (8) highly correlated variables:
#     ['is_magnetic', 'num_magnetic_sites', 'mean_atomic_numbers', 'std_atomic_numbers', 'c_parameters', 'beta_parameters', 'mean_distance_matrix', 'std_distance_matrix']
#     Following (21) vars selected: ['nelements', 'volume', 'density_atomic', 'uncorrected_energy_per_atom', 'energy_per_atom', 'formation_energy_per_atom', 'energy_above_hull', 'efermi', 'is_gap_direct', 'is_metal', 'total_magnetization_normalized_vol', 'a_parameters', 'b_parameters', 'gamma_parameters', 'min_atomic_numbers', 'total_magnetization', 'max_atomic_numbers', 'density', 'max_distance_matrix', 'ordering', 'alpha_parameters']
# Time taken for SULOV method = 25 seconds
#     Adding 0 categorical variables to reduced numeric variables  of 21
# Final list of selected 21 vars after SULOV = ['nelements', 'volume', 'density_atomic', 'uncorrected_energy_per_atom', 'energy_per_atom', 'formation_energy_per_atom', 'energy_above_hull', 'efermi', 'is_gap_direct', 'is_metal', 'total_magnetization_normalized_vol', 'a_parameters', 'b_parameters', 'gamma_parameters', 'min_atomic_numbers', 'total_magnetization', 'max_atomic_numbers', 'density', 'max_distance_matrix', 'ordering', 'alpha_parameters']
# Converting all features to numeric before sending to XGBoost...
# #######################################################################################
# #####    R E C U R S I V E   X G B O O S T : F E A T U R E   S E L E C T I O N  #######
# #######################################################################################
#     using regular XGBoost
#     Taking top 5 features per iteration...
#     Number of booster rounds = 100
#         Selected: ['is_metal', 'formation_energy_per_atom', 'efermi', 'ordering', 'max_atomic_numbers']
#             Time taken for regular XGBoost feature selection = 76 seconds
#         Selected: ['is_metal', 'formation_energy_per_atom', 'efermi', 'ordering', 'max_atomic_numbers']
#             Time taken for regular XGBoost feature selection = 32 seconds
#         Selected: ['is_metal', 'max_atomic_numbers', 'min_atomic_numbers', 'ordering', 'density']
#             Time taken for regular XGBoost feature selection = 19 seconds
#         Selected: ['min_atomic_numbers', 'total_magnetization', 'max_atomic_numbers', 'density', 'max_distance_matrix']
#             Time taken for regular XGBoost feature selection = 14 seconds
#         Selected: ['max_atomic_numbers', 'density', 'ordering', 'max_distance_matrix', 'alpha_parameters']
#             Time taken for regular XGBoost feature selection = 7 seconds
#     Completed XGBoost feature selection in 150 seconds
# #######################################################################################
# #####          F E A T U R E   S E L E C T I O N   C O M P L E T E D            #######
# #######################################################################################
# Selected 10 important features:
# ['is_metal', 'formation_energy_per_atom', 'efermi', 'ordering', 'max_atomic_numbers', 'min_atomic_numbers', 'density', 'total_magnetization', 'max_distance_matrix', 'alpha_parameters']
# Total Time taken for featurewiz selection = 175 seconds
# Output contains a list of 10 important features and a train dataframe
# ['is_metal', 'formation_energy_per_atom', 'efermi', 'ordering', 'max_atomic_numbers', 'min_atomic_numbers', 'density', 'total_magnetization', 'max_distance_matrix', 'alpha_parameters']

# %%
from featurewiz import FeatureWiz
fwiz = FeatureWiz(feature_engg = '', nrows=None, transform_target=True, scalers="std",
        		category_encoders="auto", add_missing=False, verbose=0, imbalanced=False,
                ae_options={})
X_train_selected, y_train = fwiz.fit_transform(X_train, pd.DataFrame(y_train))
X_test_selected = fwiz.transform(X_valid)

fwiz.features
# Out:
# featurewiz is given 0.9 as correlation limit...
#     Skipping feature engineering since no feature_engg input...
#     final list of category encoders given: ['onehot', 'label']
#     final list of scalers given: [std]
# Loaded input data. Shape = (53546, 30)
# #### Starting featurewiz transform for train data ####
#     Regression models don't need targets to be transformed to numeric...
#     Single_Label Regression problem
# Shape of dataset: (53546, 30). Now we classify variables into different types...
# Time taken to define data pipeline = 1 second(s)
# No model input given...
# Lazy Transformer Pipeline created...
#     Time taken to fit dataset = 1 second(s)
#     Time taken to transform dataset = 1 second(s)
#     Shape of transformed dataset: (53546, 30)
#     Single_Label Regression problem
# Starting SULOV with 29 features...
#     there are no null values in dataset...
#     there are no null values in target column...
# Completed SULOV. 26 features selected
# Performing recursive XGBoost feature selection from 26 features...
#     time taken to run entire featurewiz = 93 second(s)
# Recursive XGBoost selected 17 features...
# #### Starting featurewiz transform for test data ####
# Loaded input data. Shape = (13387, 30)
# #### Starting lazytransform for test data ####
#     Time taken to transform dataset = 1 second(s)
#     Shape of transformed dataset: (13387, 30)
# Returning dataframe with 17 features
# ['is_metal',
#  'formation_energy_per_atom',
#  'efermi',
#  'num_magnetic_sites',
#  'max_atomic_numbers',
#  'energy_above_hull',
#  'mean_atomic_numbers',
#  'min_atomic_numbers',
#  'total_magnetization_normalized_vol',
#  'ordering',
#  'std_atomic_numbers',
#  'max_distance_matrix',
#  'a_parameters',
#  'std_distance_matrix',
#  'alpha_parameters',
#  'gamma_parameters',
#  'beta_parameters']

# %%
from sklearn.feature_selection import RFE

model = RandomForestRegressor()

rfe_selector = RFE(estimator=model, n_features_to_select=10)

X_new = rfe_selector.fit_transform(X, y)

selected_features = rfe_selector.support_

# %%
print(X.columns[selected_features])
# Out:
# Index(['energy_per_atom', 'formation_energy_per_atom', 'energy_above_hull',
#        'efermi', 'is_metal', 'ordering', 'total_magnetization_normalized_vol',
#        'num_magnetic_sites', 'mean_atomic_numbers', 'max_atomic_numbers'],
#       dtype='object')
